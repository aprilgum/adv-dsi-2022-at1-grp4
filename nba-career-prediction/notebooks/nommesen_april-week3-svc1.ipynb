# %% [markdown]
# # SVC All Features
#
# No standardisation
#
# Experimenting on kernel='poly'
#
# Pre-requisite: nommesen_april-week2-prepare_data.ipynb

# %%
import pandas as pd
import numpy as np
import math

# SKLearn
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns

import joblib

# %% [markdown]
# ## Loading the training data set

# %%
alltrain = np.load('../data/processed/alltrain.npy')

print("Dimension of training data - unsplit", alltrain.shape)

df_alltrain = pd.DataFrame(alltrain, 
             columns=['ID',
                 'Games Played', 
    'Minutes Played',
    'Points Per Game',
    'Field Goals Made',
    'Field Goals Attempts',
    'Field Goals Percent',
    '3Points Made',
    '3Points Attempts',
    '3Points Percent',
    'Free Throw Made',
    'Free Throw Attempts',
    'Free Throw Percent',
    'Offensive Rebounds',
    'Defensive Rebounds',
    'Rebounds',
    'Assists',
    'Steals',
    'Blocks',
    'Turnovers',
     'TARGET_5Yrs'
                     ])

df_alltrain['TARGET_5Yrs'] = df_alltrain['TARGET_5Yrs'].astype(dtype ='int64')
df_alltrain['ID'] = df_alltrain['ID'].astype(dtype ='str')

df_alltrain.head()
# Out:
# Dimension of training data - unsplit (8000, 21)
#        ID  Games Played  Minutes Played  Points Per Game  Field Goals Made  \
# 0  3799.0          80.0            24.3              7.8               3.0
# 1  3800.0          75.0            21.8             10.5               4.2
# 2  3801.0          85.0            19.1              4.5               1.9
# 3  3802.0          63.0            19.1              8.2               3.5
# 4  3803.0          63.0            17.8              3.7               1.7
#
#    Field Goals Attempts  Field Goals Percent  3Points Made  3Points Attempts  \
# 0                   6.4                 45.7           0.1               0.3
# 1                   7.9                 55.1          -0.3              -1.0
# 2                   4.5                 42.8           0.4               1.2
# 3                   6.7                 52.5           0.3               0.8
# 4                   3.4                 50.8           0.5               1.4
#
#    3Points Percent  ...  Free Throw Attempts  Free Throw Percent  \
# 0             22.6  ...                  2.9                72.1
# 1             34.9  ...                  3.6                67.8
# 2             34.3  ...                  0.6                75.7
# 3             23.7  ...                  1.5                66.9
# 4             13.7  ...                  0.5                54.0
#
#    Offensive Rebounds  Defensive Rebounds  Rebounds  Assists  Steals  Blocks  \
# 0                 2.2                 2.0       3.8      3.2     1.1     0.2
# 1                 3.6                 3.7       6.6      0.7     0.5     0.6
# 2                 0.6                 1.8       2.4      0.8     0.4     0.2
# 3                 0.8                 2.0       3.0      1.8     0.4     0.1
# 4                 2.4                 2.7       4.9      0.4     0.4     0.6
#
#    Turnovers  TARGET_5Yrs
# 0        1.6            1
# 1        1.4            1
# 2        0.6            1
# 3        1.9            1
# 4        0.7            1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Feature selection
# All features are used

# %%
target = df_alltrain.pop('TARGET_5Yrs')
features = df_alltrain[['Games Played', 
    'Minutes Played',
    'Points Per Game',
    'Field Goals Made',
    'Field Goals Attempts',
    'Field Goals Percent',
    '3Points Made',
    '3Points Attempts',
    '3Points Percent',
    'Free Throw Made',
    'Free Throw Attempts',
    'Free Throw Percent',
    'Offensive Rebounds',
    'Defensive Rebounds',
    'Rebounds',
    'Assists',
    'Steals',
    'Blocks',
    'Turnovers']]

# target.info()
# features.info()

# %% [markdown]
# ## Splitting data
# Split randomly the dataset with random_state=8 into 2 different sets: training data (80%) and validation data (20%)

# %%
X_train, X_val, y_train, y_val = train_test_split (features, 
                                                   target,
                                                   test_size=0.2,
                                                   random_state=8
                                                  )

print("Dimension of features training data", X_train.shape)
print("Dimension of target training data", y_train.shape)
print("Dimension of features validation data", X_val.shape)
print("Dimension of targer validation data", y_val.shape)
# Out:
# Dimension of features training data (6400, 19)
# Dimension of target training data (6400,)
# Dimension of features validation data (1600, 19)
# Dimension of targer validation data (1600,)

# %%
X_train
# Out:
#       Games Played  Minutes Played  Points Per Game  Field Goals Made  \
# 3617          64.0            13.9              4.3               1.5
# 1120          81.0            20.8              7.6               2.7
# 3873          50.0             5.6              1.4               0.5
# 153           72.0            19.3              5.0               2.0
# 2960          45.0            19.7              6.1               2.5
# ...            ...             ...              ...               ...
# 2181          74.0            46.4             18.7               7.4
# 2409          59.0            14.8              3.4               1.0
# 2033          55.0            15.6              3.3               1.1
# 1364          91.0            47.9             12.1               4.2
# 4547          67.0            26.4             12.5               5.6
#
#       Field Goals Attempts  Field Goals Percent  3Points Made  \
# 3617                   3.6                 43.0          -0.2
# 1120                   6.2                 44.8           0.4
# 3873                   1.5                 36.4           0.0
# 153                    5.0                 40.4           0.1
# 2960                   5.9                 42.1           0.1
# ...                    ...                  ...           ...
# 2181                  16.3                 45.3           0.8
# 2409                   3.2                 33.7           0.5
# 2033                   2.4                 44.4           0.6
# 1364                   9.6                 46.0           0.4
# 4547                  11.3                 49.7          -0.3
#
#       3Points Attempts  3Points Percent  Free Throw Made  Free Throw Attempts  \
# 3617              -0.1             11.9              1.4                  1.9
# 1120               1.1             12.1              1.8                  2.1
# 3873               0.5             -3.1              0.2                  0.2
# 153                0.5             25.3              0.9                  1.6
# 2960               0.4             -2.7              1.1                  1.7
# ...                ...              ...              ...                  ...
# 2181               2.3             42.2              3.1                  4.5
# 2409               1.7             14.3              1.3                  2.0
# 2033               1.8             32.0              0.7                  1.0
# 1364               1.3             -0.6              3.2                  4.6
# 4547              -0.7             -4.8              2.0                  3.0
#
#       Free Throw Percent  Offensive Rebounds  Defensive Rebounds  Rebounds  \
# 3617                69.2                 0.6                 1.7       2.2
# 1120                79.0                 1.7                 4.0       5.6
# 3873                68.6                 0.1                 0.2       0.4
# 153                 48.4                 0.7                 2.0       2.9
# 2960                62.0                 1.0                 1.5       2.6
# ...                  ...                 ...                 ...       ...
# 2181                68.0                 1.9                 6.2       8.4
# 2409                56.3                 0.7                 1.2       2.1
# 2033                72.7                 1.1                 2.3       3.3
# 1364                66.4                 3.0                 6.5       9.8
# 4547                75.8                 2.9                 4.9       8.0
#
#       Assists  Steals  Blocks  Turnovers
# 3617      0.6     0.4     0.1        0.7
# 1120      0.7     0.6     0.1        1.3
# 3873      1.5     0.4    -0.3        0.3
# 153       1.1     0.5     0.2        0.9
# 2960      1.5     0.4     0.3        1.8
# ...       ...     ...     ...        ...
# 2181      3.4     1.4     0.3        3.0
# 2409      1.5     0.9     0.1        0.7
# 2033      1.0     0.5     0.3        0.8
# 1364      4.2     0.9     0.6        1.6
# 4547      0.3     0.6     2.4        1.0
#
# [6400 rows x 19 columns]

# %% [markdown]
# ## Model Development
#
# SVC using the balanced mode

# %%
# instantiate the model (using the "balanced" mode)
svc1_train = SVC(kernel='poly', 
                 class_weight='balanced', 
                 probability=True)

# fit the model with data
svc1_train.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced', kernel='poly', probability=True)

# %%
# save the model to disk
my_model_filename = '../models/svc1.sav'
joblib.dump(svc1_train, my_model_filename)
# Out:
# ['../models/svc1.sav']

# %% [markdown]
# ## Model Evaluation

# %%
# Load the model from the file 
svc1_from_joblib = joblib.load('../models/svc1.sav')

# %%
# Predict on training set
y_pred_ontrain = svc1_from_joblib.predict(X_train)

# Accuracy
print( accuracy_score(y_pred_ontrain, y_train) )
# Out:
# 0.57265625

# %% [markdown]
# ### Prediction on validation data

# %%
y_pred_onval = svc1_from_joblib.predict(X_val)
y_pred_onval
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %% [markdown]
# ### Confusion Matrix

# %%
cnf_matrix = metrics.confusion_matrix(y_val, y_pred_onval)
cnf_matrix
# Out:
# array([[194,  63],
#        [629, 714]])

# %%
class_names = [0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label');

# %% [markdown]
# ### Accuracy, Precision, and Recall

# %%
target_names = ['career years played < 5', 'career years played >= 5']
print(classification_report(y_val, y_pred_onval, target_names=target_names))
# Out:
#                           precision    recall  f1-score   support
#
#  career years played < 5       0.24      0.75      0.36       257
# career years played >= 5       0.92      0.53      0.67      1343
#
#                 accuracy                           0.57      1600
#                macro avg       0.58      0.64      0.52      1600
#             weighted avg       0.81      0.57      0.62      1600

# %% [markdown]
# ### ROC

# %%
# y_pred_proba = logreg.predict_proba(X_test)[::,1]
y_proba_onval = svc1_from_joblib.predict_proba(X_val)[::,1]  # official
fpr, tpr, _ = metrics.roc_curve(y_val,  y_proba_onval)
auc = metrics.roc_auc_score(y_val, y_proba_onval)

plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ## Test on unseen data

# %% [markdown]
# ### Loading the test data set

# %%
test = np.load('../data/processed/test.npy')

print("Dimension of training data - unsplit", test.shape)

df_test = pd.DataFrame(test, 
             columns=['ID',
                 'Games Played', 
    'Minutes Played',
    'Points Per Game',
    'Field Goals Made',
    'Field Goals Attempts',
    'Field Goals Percent',
    '3Points Made',
    '3Points Attempts',
    '3Points Percent',
    'Free Throw Made',
    'Free Throw Attempts',
    'Free Throw Percent',
    'Offensive Rebounds',
    'Defensive Rebounds',
    'Rebounds',
    'Assists',
    'Steals',
    'Blocks',
    'Turnovers'
                     ])

df_test['ID'] = df_test['ID'].astype(int)
df_test['ID'] = df_test['ID'].astype(str)

# df_test_indexed=df_test.set_index('ID')

df_test.head()
# Out:
# Dimension of training data - unsplit (3799, 20)
#   ID  Games Played  Minutes Played  Points Per Game  Field Goals Made  \
# 0  0          56.0             9.1              4.0               1.6
# 1  1          43.0            19.3             10.1               3.7
# 2  2          82.0            33.9             11.3               4.9
# 3  3          86.0            44.7             18.8               6.8
# 4  4          58.0            12.3              4.7               1.6
#
#    Field Goals Attempts  Field Goals Percent  3Points Made  3Points Attempts  \
# 0                   3.7                 43.7           0.1               0.3
# 1                   8.1                 46.0           0.6               1.7
# 2                  10.6                 45.6           0.5               1.9
# 3                  15.9                 42.9           0.5               1.8
# 4                   4.0                 40.0           0.5               1.7
#
#    3Points Percent  Free Throw Made  Free Throw Attempts  Free Throw Percent  \
# 0              7.3              0.7                  1.2                63.4
# 1             35.1              1.8                  2.5                75.3
# 2             44.8              1.8                  2.7                71.2
# 3             13.5              4.5                  6.3                70.9
# 4             38.7              1.1                  1.3                76.9
#
#    Offensive Rebounds  Defensive Rebounds  Rebounds  Assists  Steals  Blocks  \
# 0                 1.2                 0.8       1.7      0.4     0.2     0.3
# 1                 0.5                 0.9       1.5      3.5     0.6     0.0
# 2                 1.3                 3.3       4.5      2.5     1.3     0.3
# 3                 1.5                 3.2       5.0      4.1     0.9     0.1
# 4                 0.2                 0.6       0.9      1.5     0.5    -0.4
#
#    Turnovers
# 0        0.8
# 1        1.8
# 2        2.0
# 3        3.6
# 4        0.9

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3799 entries, 0 to 3798
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    3799 non-null   object
#  1   Games Played          3799 non-null   float64
#  2   Minutes Played        3799 non-null   float64
#  3   Points Per Game       3799 non-null   float64
#  4   Field Goals Made      3799 non-null   float64
#  5   Field Goals Attempts  3799 non-null   float64
#  6   Field Goals Percent   3799 non-null   float64
#  7   3Points Made          3799 non-null   float64
#  8   3Points Attempts      3799 non-null   float64
#  9   3Points Percent       3799 non-null   float64
#  10  Free Throw Made       3799 non-null   float64
#  11  Free Throw Attempts   3799 non-null   float64
#  12  Free Throw Percent    3799 non-null   float64
#  13  Offensive Rebounds    3799 non-null   float64
#  14  Defensive Rebounds    3799 non-null   float64
#  15  Rebounds              3799 non-null   float64
#  16  Assists               3799 non-null   float64
#  17  Steals                3799 non-null   float64
#  18  Blocks                3799 non-null   float64
#  19  Turnovers             3799 non-null   float64
# dtypes: float64(19), object(1)
# memory usage: 593.7+ KB

# %%
df_features_test = df_test[['Games Played', 
    'Minutes Played',
    'Points Per Game',
    'Field Goals Made',
    'Field Goals Attempts',
    'Field Goals Percent',
    '3Points Made',
    '3Points Attempts',
    '3Points Percent',
    'Free Throw Made',
    'Free Throw Attempts',
    'Free Throw Percent',
    'Offensive Rebounds',
    'Defensive Rebounds',
    'Rebounds',
    'Assists',
    'Steals',
    'Blocks',
    'Turnovers']]

df_features_test.head()
# Out:
#    Games Played  Minutes Played  Points Per Game  Field Goals Made  \
# 0          56.0             9.1              4.0               1.6
# 1          43.0            19.3             10.1               3.7
# 2          82.0            33.9             11.3               4.9
# 3          86.0            44.7             18.8               6.8
# 4          58.0            12.3              4.7               1.6
#
#    Field Goals Attempts  Field Goals Percent  3Points Made  3Points Attempts  \
# 0                   3.7                 43.7           0.1               0.3
# 1                   8.1                 46.0           0.6               1.7
# 2                  10.6                 45.6           0.5               1.9
# 3                  15.9                 42.9           0.5               1.8
# 4                   4.0                 40.0           0.5               1.7
#
#    3Points Percent  Free Throw Made  Free Throw Attempts  Free Throw Percent  \
# 0              7.3              0.7                  1.2                63.4
# 1             35.1              1.8                  2.5                75.3
# 2             44.8              1.8                  2.7                71.2
# 3             13.5              4.5                  6.3                70.9
# 4             38.7              1.1                  1.3                76.9
#
#    Offensive Rebounds  Defensive Rebounds  Rebounds  Assists  Steals  Blocks  \
# 0                 1.2                 0.8       1.7      0.4     0.2     0.3
# 1                 0.5                 0.9       1.5      3.5     0.6     0.0
# 2                 1.3                 3.3       4.5      2.5     1.3     0.3
# 3                 1.5                 3.2       5.0      4.1     0.9     0.1
# 4                 0.2                 0.6       0.9      1.5     0.5    -0.4
#
#    Turnovers
# 0        0.8
# 1        1.8
# 2        2.0
# 3        3.6
# 4        0.9

# %% [markdown]
# ### Predictions

# %%
# Use the loaded model to make predictions 
y_pred_ontest = svc1_from_joblib.predict(df_features_test)

df_test_predictions = pd.DataFrame(y_pred_ontest, columns=['TARGET_5Yrs'])

df_test_predictions.TARGET_5Yrs.value_counts()
# Out:
# 0    1908
# 1    1891
# Name: TARGET_5Yrs, dtype: int64

# %%
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

sns.countplot(x = 'TARGET_5Yrs',
              data = df_test_predictions,
              palette = 'hls'
             )
plt.show()
plt.savefig('count_plot')

# %% [markdown]
# ### Submit Prediction to Kaggle

# %%
# Use the loaded model to make predictions 
y_test = svc1_from_joblib.predict_proba(df_features_test)

# %%
y_test
# Out:
# array([[0.22012097, 0.77987903],
#        [0.22365607, 0.77634393],
#        [0.05121069, 0.94878931],
#        ...,
#        [0.24367964, 0.75632036],
#        [0.03567329, 0.96432671],
#        [0.2184083 , 0.7815917 ]])

# %%
df_test_probabilites = pd.DataFrame(y_test, 
             columns=['TARGET_5Yrs_0',
                 'TARGET_5Yrs'
                     ])

# %%
df_test_probabilites.head()
# Out:
#    TARGET_5Yrs_0  TARGET_5Yrs
# 0       0.220121     0.779879
# 1       0.223656     0.776344
# 2       0.051211     0.948789
# 3       0.057242     0.942758
# 4       0.238948     0.761052

# %%
output = df_test.join(df_test_probabilites)
output=output.set_index('ID')

output
# Out:
#       Games Played  Minutes Played  Points Per Game  Field Goals Made  \
# ID
# 0             56.0             9.1              4.0               1.6
# 1             43.0            19.3             10.1               3.7
# 2             82.0            33.9             11.3               4.9
# 3             86.0            44.7             18.8               6.8
# 4             58.0            12.3              4.7               1.6
# ...            ...             ...              ...               ...
# 3794          84.0            21.2              8.7               3.4
# 3795          49.0            16.3              6.4               2.9
# 3796          53.0             9.9              2.1               0.8
# 3797          89.0            38.3             14.5               5.4
# 3798          55.0            12.0              3.0               1.1
#
#       Field Goals Attempts  Field Goals Percent  3Points Made  \
# ID
# 0                      3.7                 43.7           0.1
# 1                      8.1                 46.0           0.6
# 2                     10.6                 45.6           0.5
# 3                     15.9                 42.9           0.5
# 4                      4.0                 40.0           0.5
# ...                    ...                  ...           ...
# 3794                   6.7                 50.2           0.0
# 3795                   6.6                 44.4          -0.1
# 3796                   1.8                 43.1          -0.4
# 3797                  11.8                 45.2           0.5
# 3798                   2.5                 42.3           0.1
#
#       3Points Attempts  3Points Percent  Free Throw Made  ...  \
# ID                                                        ...
# 0                  0.3              7.3              0.7  ...
# 1                  1.7             35.1              1.8  ...
# 2                  1.9             44.8              1.8  ...
# 3                  1.8             13.5              4.5  ...
# 4                  1.7             38.7              1.1  ...
# ...                ...              ...              ...  ...
# 3794               0.0             -4.5              1.7  ...
# 3795              -0.4             19.8              1.0  ...
# 3796              -0.6              1.9              0.6  ...
# 3797               1.2             24.7              2.5  ...
# 3798               0.6             11.7              0.9  ...
#
#       Free Throw Percent  Offensive Rebounds  Defensive Rebounds  Rebounds  \
# ID
# 0                   63.4                 1.2                 0.8       1.7
# 1                   75.3                 0.5                 0.9       1.5
# 2                   71.2                 1.3                 3.3       4.5
# 3                   70.9                 1.5                 3.2       5.0
# 4                   76.9                 0.2                 0.6       0.9
# ...                  ...                 ...                 ...       ...
# 3794                68.1                 1.9                 2.3       3.9
# 3795                50.2                 1.7                 2.8       4.4
# 3796                63.9                 0.7                 1.0       1.7
# 3797                89.2                 1.5                 4.0       5.5
# 3798                76.7                 0.7                 2.0       2.6
#
#       Assists  Steals  Blocks  Turnovers  TARGET_5Yrs_0  TARGET_5Yrs
# ID
# 0         0.4     0.2     0.3        0.8       0.220121     0.779879
# 1         3.5     0.6     0.0        1.8       0.223656     0.776344
# 2         2.5     1.3     0.3        2.0       0.051211     0.948789
# 3         4.1     0.9     0.1        3.6       0.057242     0.942758
# 4         1.5     0.5    -0.4        0.9       0.238948     0.761052
# ...       ...     ...     ...        ...            ...          ...
# 3794      1.5     0.6     0.3        2.0       0.052801     0.947199
# 3795      0.4     0.4     0.4        0.7       0.230696     0.769304
# 3796      0.4     0.4     0.2        0.5       0.243680     0.756320
# 3797      3.7     1.3     0.3        2.4       0.035673     0.964327
# 3798      0.6     0.3     0.2        1.2       0.218408     0.781592
#
# [3799 rows x 21 columns]

# %%
output['TARGET_5Yrs'].to_csv('../models/nommesen_april_week3_model-svc1.csv')
